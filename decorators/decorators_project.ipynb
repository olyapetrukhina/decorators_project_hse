# %% [markdown]
# # Домашнее задание: декораторы

# %% [markdown]
# ## Импорт библиотек, установка констант

# %%
import requests
import time
import re
from functools import wraps

from random import randint

# %%
BOOK_PATH = 'https://www.gutenberg.org/files/2638/2638-0.txt'

# %% [markdown]
# ## Задание 1

# %%
def benchmark(func):
    """
    Декоратор, выводящий время, которое заняло выполнение декорируемой функции
    """
    @wraps(func)


    def wrapper(*args, **kwargs):
        start_time = time.perf_counter()
        result = func(*args, **kwargs)
        end_time = time.perf_counter()
        print(f'Время выполнения функции {func.__name__}: {end_time - start_time:.6f} секунд')
        return result
    return wrapper

# %%
@benchmark
# def get_webpage():
#     import requests
#     webpage = requests.get('https://stepik.org')

# get_webpage()
# Out:
# Время выполнения функции get_webpage: 0.664468 секунд

# %%
@benchmark
# def fib(n):
#     if n < 2:
#         return n
#     return fib(n-2) + fib(n-1)

# fib(3)
# Out:
# Функции fib потребовалось 0.000001 секунд
# Функции fib потребовалось 0.000001 секунд
# Функции fib потребовалось 0.000001 секунд
# Функции fib потребовалось 0.001665 секунд
# Функции fib потребовалось 0.003773 секунд
# 2

# %% [markdown]
# ## Задание 2

# %%
def logging(func):
    """
    Декоратор, который выводит параметры с которыми была вызвана функция
    """
    @wraps(func)

    def wrapper(*args, **kwargs):
        args_str = ", ".join(repr(arg) for arg in args)
        kwargs_dict = {key: value for key, value in kwargs.items()}
        result = func(*args, **kwargs)
        print(f'Функция {func.__name__} вызвана с параметрами: ({args_str}), {kwargs_dict}')
        return result

    return wrapper

# %%
@logging
# def final_price(*prices, discount=1, **kwargs):
#     low = kwargs.get("price_low", min(prices))
#     high = kwargs.get("price_high", max(prices))
#     return [price - price * discount / 100 for price in prices if low <= price <= high]

# print(final_price(100, 200, 300, 400, 500, discount=5))
# print(final_price(100, 200, 300, 400, 500, discount=5, price_low=200))
# print(final_price(100, 200, 300, 400, 500, discount=5, price_high=200))
# print(final_price(100, 200, 300, 400, 500, discount=5, price_low=200, price_high=350))
# Out:
# Функция final_price вызвана с параметрами: (100, 200, 300, 400, 500), {'discount': 5}
# [95.0, 190.0, 285.0, 380.0, 475.0]
# Функция final_price вызвана с параметрами: (100, 200, 300, 400, 500), {'discount': 5, 'price_low': 200}
# [190.0, 285.0, 380.0, 475.0]
# Функция final_price вызвана с параметрами: (100, 200, 300, 400, 500), {'discount': 5, 'price_high': 200}
# [95.0, 190.0]
# Функция final_price вызвана с параметрами: (100, 200, 300, 400, 500), {'discount': 5, 'price_low': 200, 'price_high': 350}
# [190.0, 285.0]

# %% [markdown]
# ## Задание 3

# %%
def counter(func):
    """
    Декоратор, считающий и выводящий количество вызовов декорируемой функции
    """
    @wraps(func)

    def wrapper(*args, **kwargs):
        wrapper.calls += 1
        result = func(*args, **kwargs)
        print(f"Функция {func.__name__} была вызвана {wrapper.calls} раз(а)")
        return result

    wrapper.calls = 0
    return wrapper

# %%
@counter
# def final_price(*prices, discount=1, **kwargs):
#     low = kwargs.get("price_low", min(prices))
#     high = kwargs.get("price_high", max(prices))
#     return [price - price * discount / 100 for price in prices if low <= price <= high]

# print(final_price(100, 200, 300, 400, 500, discount=5))
# print(final_price(100, 200, 300, 400, 500, discount=5, price_low=200))
# print(final_price(100, 200, 300, 400, 500, discount=5, price_high=200))
# print(final_price(100, 200, 300, 400, 500, discount=5, price_low=200, price_high=350))
# Out:
# Функция final_price была вызвана 1 раз(а)
# [95.0, 190.0, 285.0, 380.0, 475.0]
# Функция final_price была вызвана 2 раз(а)
# [190.0, 285.0, 380.0, 475.0]
# Функция final_price была вызвана 3 раз(а)
# [95.0, 190.0]
# Функция final_price была вызвана 4 раз(а)
# [190.0, 285.0]

# %%
@counter
# def fib(n):
#     if n < 2:
#         return n
#     return fib(n-2) + fib(n-1)

# fib(3)
# Out:
# Функция fib была вызвана 2 раз(а)
# Функция fib была вызвана 4 раз(а)
# Функция fib была вызвана 5 раз(а)
# Функция fib была вызвана 5 раз(а)
# Функция fib была вызвана 5 раз(а)
# 2

# %% [markdown]
# ## Задание 4

# %%
def memo(func):
  """
  Декоратор, запоминающий результаты исполнения функции func, чьи аргументы args должны быть хешируемыми
  """
  cache = {}
  @wraps(func)
  def fmemo(*args):
      if args not in cache:
          cache[args] = func(*args)
      return cache[args]
  fmemo.cache = cache
  return fmemo

# %% [markdown]
# ## Тестирование

# %%
@counter
@logging
@benchmark
def word_count(word, url=BOOK_PATH):
    """
    Функция для посчета указанного слова на html-странице
    """

    # отправляем запрос в библиотеку Gutenberg и забираем текст
    raw = requests.get(url).text

    # заменяем в тексте все небуквенные символы на пробелы
    processed_book = re.sub('[\W]+' , ' ', raw).lower()

    # считаем
    cnt = len(re.findall(word.lower(), processed_book))

    return f"Cлово {word} встречается {cnt} раз"

print(word_count('whole'))
# Out:
# Время выполнения функции word_count: 0.440753 секунд
# Функция word_count вызвана с параметрами: ('whole'), {}
# Функция word_count была вызвана 1 раз(а)
# Cлово whole встречается 176 раз

# %%
def fib(n):
    if n < 2:
        return n
    return fib(n-2) + fib(n-1)

# %%
# измеряем время выполнения
@benchmark
def fib(n):
    if n < 2:
        return n
    return fib(n-2) + fib(n-1)

fib(20)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000116 секунд
# Время выполнения функции fib: 0.000218 секунд
# Время выполнения функции fib: 0.000367 секунд
# Время выполнения функции fib: 0.003343 секунд
# Время выполнения функции fib: 0.004993 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000039 секунд
# Время выполнения функции fib: 0.000068 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000120 секунд
# Время выполнения функции fib: 0.000217 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000058 секунд
# Время выполнения функции fib: 0.000115 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000034 секунд
# Время выполнения функции fib: 0.000063 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000033 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000122 секунд
# Время выполнения функции fib: 0.000234 секунд
# Время выполнения функции fib: 0.000377 секунд
# Время выполнения функции fib: 0.000624 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000121 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.001255 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000037 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000033 секунд
# Время выполнения функции fib: 0.000064 секунд
# Время выполнения функции fib: 0.000133 секунд
# Время выполнения функции fib: 0.001506 секунд
# Время выполнения функции fib: 0.001656 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000079 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000034 секунд
# Время выполнения функции fib: 0.000064 секунд
# Время выполнения функции fib: 0.000220 секунд
# Время выполнения функции fib: 0.000329 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000063 секунд
# Время выполнения функции fib: 0.000121 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000122 секунд
# Время выполнения функции fib: 0.000212 секунд
# Время выполнения функции fib: 0.000378 секунд
# Время выполнения функции fib: 0.000735 секунд
# Время выполнения функции fib: 0.002429 секунд
# Время выполнения функции fib: 0.003082 секунд
# Время выполнения функции fib: 0.008105 секунд
# Время выполнения функции fib: 0.017617 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000118 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000058 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000058 секунд
# Время выполнения функции fib: 0.000119 секунд
# Время выполнения функции fib: 0.000207 секунд
# Время выполнения функции fib: 0.000353 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000058 секунд
# Время выполнения функции fib: 0.000119 секунд
# Время выполнения функции fib: 0.000209 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000036 секунд
# Время выполнения функции fib: 0.000002 секунд
# Время выполнения функции fib: 0.010214 секунд
# Время выполнения функции fib: 0.010251 секунд
# Время выполнения функции fib: 0.010312 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000915 секунд
# Время выполнения функции fib: 0.000955 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000034 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000034 секунд
# Время выполнения функции fib: 0.000066 секунд
# Время выполнения функции fib: 0.000131 секунд
# Время выполнения функции fib: 0.001121 секунд
# Время выполнения функции fib: 0.011468 секунд
# Время выполнения функции fib: 0.011710 секунд
# Время выполнения функции fib: 0.012094 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000063 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000123 секунд
# Время выполнения функции fib: 0.000216 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000120 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000114 секунд
# Время выполнения функции fib: 0.000143 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000047 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000137 секунд
# Время выполнения функции fib: 0.000310 секунд
# Время выполнения функции fib: 0.000459 секунд
# Время выполнения функции fib: 0.000705 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000124 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000054 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000064 секунд
# Время выполнения функции fib: 0.000148 секунд
# Время выполнения функции fib: 0.000238 секунд
# Время выполнения функции fib: 0.000390 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000121 секунд
# Время выполнения функции fib: 0.000210 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000124 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000174 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000120 секунд
# Время выполнения функции fib: 0.000325 секунд
# Время выполнения функции fib: 0.000480 секунд
# Время выполнения функции fib: 0.000720 секунд
# Время выполнения функции fib: 0.001140 секунд
# Время выполнения функции fib: 0.001875 секунд
# Время выполнения функции fib: 0.014001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000118 секунд
# Время выполнения функции fib: 0.000207 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000118 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000065 секунд
# Время выполнения функции fib: 0.000124 секунд
# Время выполнения функции fib: 0.000213 секунд
# Время выполнения функции fib: 0.000360 секунд
# Время выполнения функции fib: 0.000596 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000133 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000119 секунд
# Время выполнения функции fib: 0.000210 секунд
# Время выполнения функции fib: 0.000399 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000063 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000119 секунд
# Время выполнения функции fib: 0.000212 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000033 секунд
# Время выполнения функции fib: 0.000063 секунд
# Время выполнения функции fib: 0.000124 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000037 секунд
# Время выполнения функции fib: 0.000067 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000101 секунд
# Время выполнения функции fib: 0.000133 секунд
# Время выполнения функции fib: 0.000193 секунд
# Время выполнения функции fib: 0.000290 секунд
# Время выполнения функции fib: 0.000442 секунд
# Время выполнения функции fib: 0.000685 секунд
# Время выполнения функции fib: 0.001185 секунд
# Время выполнения функции fib: 0.001812 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000121 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000120 секунд
# Время выполнения функции fib: 0.000213 секунд
# Время выполнения функции fib: 0.000363 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000119 секунд
# Время выполнения функции fib: 0.000208 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000067 секунд
# Время выполнения функции fib: 0.000126 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000033 секунд
# Время выполнения функции fib: 0.000064 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000124 секунд
# Время выполнения функции fib: 0.000228 секунд
# Время выполнения функции fib: 0.000385 секунд
# Время выполнения функции fib: 0.000623 секунд
# Время выполнения функции fib: 0.001016 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000119 секунд
# Время выполнения функции fib: 0.000209 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000119 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000119 секунд
# Время выполнения функции fib: 0.000208 секунд
# Время выполнения функции fib: 0.000357 секунд
# Время выполнения функции fib: 0.000596 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000133 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000130 секунд
# Время выполнения функции fib: 0.000222 секунд
# Время выполнения функции fib: 0.000385 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000122 секунд
# Время выполнения функции fib: 0.000214 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000119 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000129 секунд
# Время выполнения функции fib: 0.000218 секунд
# Время выполнения функции fib: 0.000366 секунд
# Время выполнения функции fib: 0.000610 секунд
# Время выполнения функции fib: 0.001024 секунд
# Время выполнения функции fib: 0.001715 секунд
# Время выполнения функции fib: 0.002760 секунд
# Время выполнения функции fib: 0.004602 секунд
# Время выполнения функции fib: 0.018634 секунд
# Время выполнения функции fib: 0.036283 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000057 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000047 секунд
# Время выполнения функции fib: 0.000078 секунд
# Время выполнения функции fib: 0.000168 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000034 секунд
# Время выполнения функции fib: 0.000063 секунд
# Время выполнения функции fib: 0.000130 секунд
# Время выполнения функции fib: 0.000223 секунд
# Время выполнения функции fib: 0.000425 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000034 секунд
# Время выполнения функции fib: 0.000079 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000071 секунд
# Время выполнения функции fib: 0.000133 секунд
# Время выполнения функции fib: 0.000251 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000121 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000033 секунд
# Время выполнения функции fib: 0.000065 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000050 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000037 секунд
# Время выполнения функции fib: 0.000069 секунд
# Время выполнения функции fib: 0.000150 секунд
# Время выполнения функции fib: 0.000246 секунд
# Время выполнения функции fib: 0.000398 секунд
# Время выполнения функции fib: 0.000681 секунд
# Время выполнения функции fib: 0.001142 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000033 секунд
# Время выполнения функции fib: 0.000064 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000033 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000074 секунд
# Время выполнения функции fib: 0.000138 секунд
# Время выполнения функции fib: 0.000232 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000125 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000126 секунд
# Время выполнения функции fib: 0.000225 секунд
# Время выполнения функции fib: 0.000380 секунд
# Время выполнения функции fib: 0.000642 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000028 секунд
# Время выполнения функции fib: 0.000206 секунд
# Время выполнения функции fib: 0.000275 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000065 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000037 секунд
# Время выполнения функции fib: 0.000076 секунд
# Время выполнения функции fib: 0.000137 секунд
# Время выполнения функции fib: 0.000233 секунд
# Время выполнения функции fib: 0.000538 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000042 секунд
# Время выполнения функции fib: 0.000072 секунд
# Время выполнения функции fib: 0.000131 секунд
# Время выполнения функции fib: 0.000221 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000123 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000063 секунд
# Время выполнения функции fib: 0.000123 секунд
# Время выполнения функции fib: 0.000224 секунд
# Время выполнения функции fib: 0.000378 секунд
# Время выполнения функции fib: 0.000629 секунд
# Время выполнения функции fib: 0.001198 секунд
# Время выполнения функции fib: 0.001871 секунд
# Время выполнения функции fib: 0.003051 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000056 секунд
# Время выполнения функции fib: 0.000088 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000033 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000063 секунд
# Время выполнения функции fib: 0.000126 секунд
# Время выполнения функции fib: 0.000253 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000121 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000034 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000125 секунд
# Время выполнения функции fib: 0.000213 секунд
# Время выполнения функции fib: 0.000363 секунд
# Время выполнения функции fib: 0.000646 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000117 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000137 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000123 секунд
# Время выполнения функции fib: 0.000290 секунд
# Время выполнения функции fib: 0.000435 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000057 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000054 секунд
# Время выполнения функции fib: 0.000089 секунд
# Время выполнения функции fib: 0.000183 секунд
# Время выполнения функции fib: 0.063852 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000123 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000063 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000070 секунд
# Время выполнения функции fib: 0.000101 секунд
# Время выполнения функции fib: 0.000165 секунд
# Время выполнения функции fib: 0.000260 секунд
# Время выполнения функции fib: 0.000417 секунд
# Время выполнения функции fib: 0.064303 секунд
# Время выполнения функции fib: 0.064767 секунд
# Время выполнения функции fib: 0.065447 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000042 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000034 секунд
# Время выполнения функции fib: 0.000065 секунд
# Время выполнения функции fib: 0.000139 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000064 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000121 секунд
# Время выполнения функции fib: 0.000215 секунд
# Время выполнения функции fib: 0.000384 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000053 секунд
# Время выполнения функции fib: 0.000084 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000033 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000063 секунд
# Время выполнения функции fib: 0.000126 секунд
# Время выполнения функции fib: 0.000240 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000124 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000039 секунд
# Время выполнения функции fib: 0.000070 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000033 секунд
# Время выполнения функции fib: 0.000064 секунд
# Время выполнения функции fib: 0.000125 секунд
# Время выполнения функции fib: 0.000225 секунд
# Время выполнения функции fib: 0.000379 секунд
# Время выполнения функции fib: 0.000648 секунд
# Время выполнения функции fib: 0.001063 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000167 секунд
# Время выполнения функции fib: 0.000196 секунд
# Время выполнения функции fib: 0.000265 секунд
# Время выполнения функции fib: 0.000374 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000033 секунд
# Время выполнения функции fib: 0.000067 секунд
# Время выполнения функции fib: 0.000129 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000033 секунд
# Время выполнения функции fib: 0.000066 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000034 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000034 секунд
# Время выполнения функции fib: 0.000066 секунд
# Время выполнения функции fib: 0.000140 секунд
# Время выполнения функции fib: 0.000239 секунд
# Время выполнения функции fib: 0.000399 секунд
# Время выполнения функции fib: 0.000807 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000125 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000122 секунд
# Время выполнения функции fib: 0.000214 секунд
# Время выполнения функции fib: 0.000371 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000058 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000050 секунд
# Время выполнения функции fib: 0.000081 секунд
# Время выполнения функции fib: 0.000148 секунд
# Время выполнения функции fib: 0.000235 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000123 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000046 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000051 секунд
# Время выполнения функции fib: 0.000099 секунд
# Время выполнения функции fib: 0.000198 секунд
# Время выполнения функции fib: 0.000305 секунд
# Время выполнения функции fib: 0.000466 секунд
# ...
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000065 секунд
# Время выполнения функции fib: 0.000132 секунд
# Время выполнения функции fib: 0.000366 секунд
# Время выполнения функции fib: 0.000531 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000071 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000057 секунд
# Время выполнения функции fib: 0.000115 секунд
# Время выполнения функции fib: 0.000215 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000121 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000038 секунд
# Время выполнения функции fib: 0.000068 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000120 секунд
# Время выполнения функции fib: 0.000217 секунд
# Время выполнения функции fib: 0.000368 секунд
# Время выполнения функции fib: 0.000613 секунд
# Время выполнения функции fib: 0.001177 секунд
# Время выполнения функции fib: 0.001871 секунд
# Время выполнения функции fib: 0.012661 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000122 секунд
# Время выполнения функции fib: 0.000214 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000061 секунд
# Время выполнения функции fib: 0.000123 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000075 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000124 секунд
# Время выполнения функции fib: 0.000229 секунд
# Время выполнения функции fib: 0.000381 секунд
# Время выполнения функции fib: 0.000626 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000037 секунд
# Время выполнения функции fib: 0.000115 секунд
# Время выполнения функции fib: 0.000190 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000077 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000033 секунд
# Время выполнения функции fib: 0.000079 секунд
# Время выполнения функции fib: 0.003534 секунд
# Время выполнения функции fib: 0.003647 секунд
# Время выполнения функции fib: 0.003884 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000144 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000028 секунд
# Время выполнения функции fib: 0.000057 секунд
# Время выполнения функции fib: 0.000114 секунд
# Время выполнения функции fib: 0.000287 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000028 секунд
# Время выполнения функции fib: 0.000056 секунд
# Время выполнения функции fib: 0.000113 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000057 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000058 секунд
# Время выполнения функции fib: 0.000116 секунд
# Время выполнения функции fib: 0.000201 секунд
# Время выполнения функции fib: 0.000342 секунд
# Время выполнения функции fib: 0.000657 секунд
# Время выполнения функции fib: 0.004572 секунд
# Время выполнения функции fib: 0.005227 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000057 секунд
# Время выполнения функции fib: 0.000115 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000119 секунд
# Время выполнения функции fib: 0.000205 секунд
# Время выполнения функции fib: 0.000357 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000058 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000058 секунд
# Время выполнения функции fib: 0.000116 секунд
# Время выполнения функции fib: 0.000202 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000028 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000057 секунд
# Время выполнения функции fib: 0.000113 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000028 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000057 секунд
# Время выполнения функции fib: 0.000113 секунд
# Время выполнения функции fib: 0.000200 секунд
# Время выполнения функции fib: 0.000341 секунд
# Время выполнения функции fib: 0.000571 секунд
# Время выполнения функции fib: 0.000955 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000095 секунд
# Время выполнения функции fib: 0.000125 секунд
# Время выполнения функции fib: 0.000181 секунд
# Время выполнения функции fib: 0.000273 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000028 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000057 секунд
# Время выполнения функции fib: 0.000115 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000028 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000028 секунд
# Время выполнения функции fib: 0.000057 секунд
# Время выполнения функции fib: 0.000113 секунд
# Время выполнения функции fib: 0.000201 секунд
# Время выполнения функции fib: 0.000344 секунд
# Время выполнения функции fib: 0.000645 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000043 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000136 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000060 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000059 секунд
# Время выполнения функции fib: 0.000122 секунд
# Время выполнения функции fib: 0.000211 секунд
# Время выполнения функции fib: 0.000384 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000058 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000041 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000027 секунд
# Время выполнения функции fib: 0.000055 секунд
# Время выполнения функции fib: 0.000122 секунд
# Время выполнения функции fib: 0.000207 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000028 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000028 секунд
# Время выполнения функции fib: 0.000055 секунд
# Время выполнения функции fib: 0.000111 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000029 секунд
# Время выполнения функции fib: 0.000058 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000030 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000000 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000062 секунд
# Время выполнения функции fib: 0.000122 секунд
# Время выполнения функции fib: 0.000208 секунд
# Время выполнения функции fib: 0.000347 секунд
# Время выполнения функции fib: 0.000583 секунд
# Время выполнения функции fib: 0.000997 секунд
# Время выполнения функции fib: 0.001674 секунд
# Время выполнения функции fib: 0.002659 секунд
# Время выполнения функции fib: 0.007921 секунд
# Время выполнения функции fib: 0.020613 секунд
# Время выполнения функции fib: 0.025521 секунд
# Время выполнения функции fib: 0.034450 секунд
# Время выполнения функции fib: 0.075566 секунд
# Время выполнения функции fib: 0.240221 секунд
# Время выполнения функции fib: 0.701931 секунд
# Время выполнения функции fib: 1.365155 секунд
# Время выполнения функции fib: 1.606024 секунд
# Время выполнения функции fib: 2.364959 секунд
# 6765

# %%
@memo
def fib(n):
    if n < 2:
        return n
    return fib(n-2) + fib(n-1)

# %%
# измеряем время выполнения
@benchmark
@memo
def fib(n):
    if n < 2:
        return n
    return fib(n-2) + fib(n-1)

fib(20)
# Out:
# Время выполнения функции fib: 0.000002 секунд
# Время выполнения функции fib: 0.000002 секунд
# Время выполнения функции fib: 0.000104 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000034 секунд
# Время выполнения функции fib: 0.000171 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000033 секунд
# Время выполнения функции fib: 0.000237 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000035 секунд
# Время выполнения функции fib: 0.000326 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000032 секунд
# Время выполнения функции fib: 0.000390 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000041 секунд
# Время выполнения функции fib: 0.000462 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000523 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000586 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000648 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000001 секунд
# Время выполнения функции fib: 0.000031 секунд
# Время выполнения функции fib: 0.000712 секунд
# 6765
